# %%
import pandas as pd

# %%
# Lire le fichier CSV
# Essayer avec différents délimiteurs et options
try:
    df = pd.read_csv('Untitled1.csv', sep=',', encoding='utf-8', error_bad_lines=False)
except pd.errors.ParserError:
    print("Erreur lors du parsing. Essayez avec un autre délimiteur ou vérifiez le format du fichier.")

# Afficher les premières lignes pour vérifier
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 # Lire le fichier CSV
#       2 # Essayer avec différents délimiteurs et options
#       3 try:
# ----> 4     df = pd.read_csv('Untitled1.csv', sep=',', encoding='utf-8', error_bad_lines=False)
#       5 except pd.errors.ParserError:
#       6     print("Erreur lors du parsing. Essayez avec un autre délimiteur ou vérifiez le format du fichier.")
#
# TypeError: read_csv() got an unexpected keyword argument 'error_bad_lines'
